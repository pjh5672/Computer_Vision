# %% [markdown]
# ## HYPERPARAMETER TUNING WITH RAY TUNE

# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir="./"):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=transform)

    testset = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=transform)

    return trainset, testset

# %%
class Net(nn.Module):
    def __init__(self, l1=120, l2=84):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.fc3 = nn.Linear(l2, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train_cifar(config, checkpoint_dir=None, data_dir=None):
    net = Net(config["l1"], config["l2"])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, testset = load_data(data_dir)

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(
        trainset, [test_abs, len(trainset) - test_abs])

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)

    for epoch in range(10):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %%
def test_accuracy(net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):
    data_dir = os.path.abspath("./data")
    load_data(data_dir)
    config = {
        "l1": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "l2": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "lr": tune.loguniform(1e-4, 1e-1),
        "batch_size": tune.choice([2, 4, 8, 16])
    }
    scheduler = ASHAScheduler(
        metric="loss",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])
    result = tune.run(
        partial(train_cifar, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = Net(best_trial.config["l1"], best_trial.config["l2"])
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc = test_accuracy(best_trained_model, device)
    print("Best trial test set accuracy: {}".format(test_acc))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to C:\my_code\Computer_Vision\Torch_Tutorial\Optimization\data\cifar-10-python.tar.gz
# 26.0%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 37.2%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 55.2%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 72.1%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 90.7%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 100.0%
# Extracting C:\my_code\Computer_Vision\Torch_Tutorial\Optimization\data\cifar-10-python.tar.gz to C:\my_code\Computer_Vision\Torch_Tutorial\Optimization\data
# Files already downloaded and verified
# 2021-07-28 00:39:33,934	INFO services.py:1274 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-07-28 00:39:46,672	WARNING experiment.py:294 -- No name detected on trainable. Using DEFAULT.
# 2021-07-28 00:39:46,673	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# 2021-07-28 00:39:46,988	ERROR syncer.py:72 -- Log sync requires rsync to be installed.
# == Status ==
# Memory usage on this node: 6.3/15.9 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/6.24 GiB heap, 0.0/3.12 GiB objects
# Result logdir: C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46
# Number of trials: 10/10 (10 PENDING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_df0ef_00000 | PENDING  |       |            8 |  128 |   16 | 0.00832281  |
# | DEFAULT_df0ef_00001 | PENDING  |       |           16 |   64 |   64 | 0.038013    |
# | DEFAULT_df0ef_00002 | PENDING  |       |            4 |   16 |    4 | 0.0278657   |
# | DEFAULT_df0ef_00003 | PENDING  |       |            4 |    8 |    4 | 0.000381076 |
# | DEFAULT_df0ef_00004 | PENDING  |       |            2 |   16 |    4 | 0.000174042 |
# | DEFAULT_df0ef_00005 | PENDING  |       |            4 |    4 |  256 | 0.000789866 |
# | DEFAULT_df0ef_00006 | PENDING  |       |           16 |  128 |  128 | 0.0207728   |
# | DEFAULT_df0ef_00007 | PENDING  |       |            4 |    8 |  256 | 0.00113064  |
# | DEFAULT_df0ef_00008 | PENDING  |       |            8 |   16 |  128 | 0.000982856 |
# | DEFAULT_df0ef_00009 | PENDING  |       |           16 |  128 |    4 | 0.000411013 |
# +---------------------+----------+-------+--------------+------+------+-------------+
#
#
# == Status ==
# Memory usage on this node: 11.8/15.9 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/6.24 GiB heap, 0.0/3.12 GiB objects
# Result logdir: C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_df0ef_00000 | RUNNING  |       |            8 |  128 |   16 | 0.00832281  |
# | DEFAULT_df0ef_00001 | RUNNING  |       |           16 |   64 |   64 | 0.038013    |
# | DEFAULT_df0ef_00002 | RUNNING  |       |            4 |   16 |    4 | 0.0278657   |
# | DEFAULT_df0ef_00003 | RUNNING  |       |            4 |    8 |    4 | 0.000381076 |
# | DEFAULT_df0ef_00004 | RUNNING  |       |            2 |   16 |    4 | 0.000174042 |
# | DEFAULT_df0ef_00005 | RUNNING  |       |            4 |    4 |  256 | 0.000789866 |
# | DEFAULT_df0ef_00006 | PENDING  |       |           16 |  128 |  128 | 0.0207728   |
# | DEFAULT_df0ef_00007 | PENDING  |       |            4 |    8 |  256 | 0.00113064  |
# | DEFAULT_df0ef_00008 | PENDING  |       |            8 |   16 |  128 | 0.000982856 |
# | DEFAULT_df0ef_00009 | PENDING  |       |           16 |  128 |    4 | 0.000411013 |
# +---------------------+----------+-------+--------------+------+------+-------------+
#
#
# (pid=24740) Files already downloaded and verified
# (pid=12976) Files already downloaded and verified
# (pid=13480) Files already downloaded and verified
# (pid=6428) Files already downloaded and verified
# (pid=13244) Files already downloaded and verified
# (pid=9092) Files already downloaded and verified
# (pid=24740) Files already downloaded and verified
# (pid=12976) Files already downloaded and verified
# (pid=13480) Files already downloaded and verified
# (pid=6428) Files already downloaded and verified
# (pid=13244) Files already downloaded and verified
# (pid=9092) Files already downloaded and verified
# (pid=12976) Traceback (most recent call last):
# (pid=12976)   File "<string>", line 1, in <module>
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 105, in spawn_main
# (pid=12976)     exitcode = _main(fd)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 115, in _main
# (pid=12976)     self = reduction.pickle.load(from_parent)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\__init__.py", line 117, in <module>
# (pid=12976)     raise err
# (pid=12976) OSError: [WinError 1455] �� �۾��� �Ϸ��ϱ� ���� ����¡ ������ �ʹ� �۽��ϴ�. Error loading "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# (pid=13480) Traceback (most recent call last):
# (pid=13480)   File "<string>", line 1, in <module>
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 105, in spawn_main
# (pid=13480)     exitcode = _main(fd)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 115, in _main
# (pid=13480)     self = reduction.pickle.load(from_parent)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\__init__.py", line 117, in <module>
# (pid=13480)     raise err
# (pid=13480) OSError: [WinError 1455] �� �۾��� �Ϸ��ϱ� ���� ����¡ ������ �ʹ� �۽��ϴ�. Error loading "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# (pid=13480) 2021-07-28 00:40:10,451	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=13480) Traceback (most recent call last):
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=13480)     self._entrypoint()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=13480)     self._status_reporter.get_checkpoint())
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=13480)     output = fn()
# (pid=13480)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=13480)     return self._get_iterator()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=13480)     return _MultiProcessingDataLoaderIter(self)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=13480)     w.start()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=13480)     self._popen = self._Popen(self)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=13480)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=13480)     return Popen(process_obj)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=13480)     reduction.dump(process_obj, to_child)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=13480)     ForkingPickler(file, protocol).dump(obj)
# (pid=13480) BrokenPipeError: [Errno 32] Broken pipe
# (pid=6428) Traceback (most recent call last):
# (pid=6428)   File "<string>", line 1, in <module>
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 105, in spawn_main
# (pid=6428)     exitcode = _main(fd)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\spawn.py", line 115, in _main
# (pid=6428)     self = reduction.pickle.load(from_parent)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\__init__.py", line 117, in <module>
# (pid=6428)     raise err
# (pid=6428) OSError: [WinError 1455] �� �۾��� �Ϸ��ϱ� ���� ����¡ ������ �ʹ� �۽��ϴ�. Error loading "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# (pid=12976) 2021-07-28 00:40:10,453	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=12976) Traceback (most recent call last):
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=12976)     self._entrypoint()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=12976)     self._status_reporter.get_checkpoint())
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=12976)     output = fn()
# (pid=12976)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=12976)     return self._get_iterator()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=12976)     return _MultiProcessingDataLoaderIter(self)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=12976)     w.start()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=12976)     self._popen = self._Popen(self)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=12976)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=12976)     return Popen(process_obj)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=12976)     reduction.dump(process_obj, to_child)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=12976)     ForkingPickler(file, protocol).dump(obj)
# (pid=12976) BrokenPipeError: [Errno 32] Broken pipe
# (pid=13480) Exception in thread Thread-2:
# (pid=13480) Traceback (most recent call last):
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\threading.py", line 916, in _bootstrap_inner
# (pid=13480)     self.run()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 267, in run
# (pid=13480)     raise e
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=13480)     self._entrypoint()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=13480)     self._status_reporter.get_checkpoint())
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=13480)     output = fn()
# (pid=13480)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=13480)     return self._get_iterator()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=13480)     return _MultiProcessingDataLoaderIter(self)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=13480)     w.start()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=13480)     self._popen = self._Popen(self)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=13480)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=13480)     return Popen(process_obj)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=13480)     reduction.dump(process_obj, to_child)
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=13480)     ForkingPickler(file, protocol).dump(obj)
# (pid=13480) BrokenPipeError: [Errno 32] Broken pipe
# (pid=13480)
# (pid=13480) Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x000002341AACDB38>>
# (pid=13480) Traceback (most recent call last):
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1203, in __del__
# (pid=12976) Exception in thread Thread-2:
# (pid=12976) Traceback (most recent call last):
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\threading.py", line 916, in _bootstrap_inner
# (pid=12976)     self.run()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 267, in run
# (pid=12976)     raise e
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=12976)     self._entrypoint()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=12976)     self._status_reporter.get_checkpoint())
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=12976)     output = fn()
# (pid=12976)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=12976)     return self._get_iterator()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=12976)     return _MultiProcessingDataLoaderIter(self)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=12976)     w.start()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=12976)     self._popen = self._Popen(self)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=12976)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=12976)     return Popen(process_obj)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=12976)     reduction.dump(process_obj, to_child)
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=12976)     ForkingPickler(file, protocol).dump(obj)
# (pid=12976) BrokenPipeError: [Errno 32] Broken pipe
# (pid=12976)
# (pid=12976) Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x000001DE7028DA90>>
# (pid=12976) Traceback (most recent call last):
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1203, in __del__
# (pid=12976)     self._shutdown_workers()
# (pid=12976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1174, in _shutdown_workers
# (pid=13480)     self._shutdown_workers()
# (pid=13480)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1174, in _shutdown_workers
# (pid=13480)     if self._persistent_workers or self._workers_status[worker_id]:
# (pid=13480) AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# (pid=6428) 2021-07-28 00:40:10,485	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=6428) Traceback (most recent call last):
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=6428)     self._entrypoint()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=6428)     self._status_reporter.get_checkpoint())
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=6428)     output = fn()
# (pid=6428)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=6428)     return self._get_iterator()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=6428)     return _MultiProcessingDataLoaderIter(self)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=6428)     w.start()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=6428)     self._popen = self._Popen(self)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=6428)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=6428)     return Popen(process_obj)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=6428)     reduction.dump(process_obj, to_child)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=6428)     ForkingPickler(file, protocol).dump(obj)
# (pid=6428) BrokenPipeError: [Errno 32] Broken pipe
# (pid=6428) Exception in thread Thread-2:
# (pid=6428) Traceback (most recent call last):
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\threading.py", line 916, in _bootstrap_inner
# (pid=6428)     self.run()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 267, in run
# (pid=6428)     raise e
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=6428)     self._entrypoint()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=6428)     self._status_reporter.get_checkpoint())
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=6428)     output = fn()
# (pid=6428)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=6428)     return self._get_iterator()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=6428)     return _MultiProcessingDataLoaderIter(self)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=6428)     w.start()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=6428)     self._popen = self._Popen(self)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=6428)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=6428)     return Popen(process_obj)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=6428)     reduction.dump(process_obj, to_child)
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=6428)     ForkingPickler(file, protocol).dump(obj)
# (pid=6428) BrokenPipeError: [Errno 32] Broken pipe
# (pid=6428)
# (pid=6428) Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x000001D6D70BDB00>>
# (pid=6428) Traceback (most recent call last):
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1203, in __del__
# (pid=6428)     self._shutdown_workers()
# (pid=6428)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 1174, in _shutdown_workers
# (pid=12976)     if self._persistent_workers or self._workers_status[worker_id]:
# (pid=12976) AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# (pid=6428)     if self._persistent_workers or self._workers_status[worker_id]:
# (pid=6428) AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# 2021-07-28 00:40:10,692	ERROR trial_runner.py:748 -- Trial DEFAULT_df0ef_00002: Error processing event.
# Traceback (most recent call last):
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py", line 718, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\ray_trial_executor.py", line 688, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\client_mode_hook.py", line 62, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\worker.py", line 1494, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=13480, ip=192.168.219.101)
#   File "python\ray\_raylet.pyx", line 501, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 451, in ray._raylet.execute_task.function_executor
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\function_manager.py", line 563, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 232, in train
#     result = self.step()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 513, in _report_thread_runner_error
#     ("Trial raised an exception. Traceback:\n{}".format(err_tb_str)
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=13480, ip=192.168.219.101)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
#     self._entrypoint()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
#     return self._get_iterator()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
#     return _MultiProcessingDataLoaderIter(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
#     w.start()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
#     self._popen = self._Popen(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
#     reduction.dump(process_obj, to_child)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# BrokenPipeError: [Errno 32] Broken pipe
# 2021-07-28 00:40:10,768	ERROR trial_runner.py:748 -- Trial DEFAULT_df0ef_00000: Error processing event.
# Traceback (most recent call last):
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py", line 718, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\ray_trial_executor.py", line 688, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\client_mode_hook.py", line 62, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\worker.py", line 1494, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=12976, ip=192.168.219.101)
#   File "python\ray\_raylet.pyx", line 501, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 451, in ray._raylet.execute_task.function_executor
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\function_manager.py", line 563, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 232, in train
#     result = self.step()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 513, in _report_thread_runner_error
#     ("Trial raised an exception. Traceback:\n{}".format(err_tb_str)
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=12976, ip=192.168.219.101)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
#     self._entrypoint()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
#     return self._get_iterator()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
#     return _MultiProcessingDataLoaderIter(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
#     w.start()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
#     self._popen = self._Popen(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
#     reduction.dump(process_obj, to_child)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# BrokenPipeError: [Errno 32] Broken pipe
# 2021-07-28 00:40:10,799	ERROR trial_runner.py:748 -- Trial DEFAULT_df0ef_00005: Error processing event.
# Traceback (most recent call last):
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py", line 718, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\ray_trial_executor.py", line 688, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\client_mode_hook.py", line 62, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\worker.py", line 1494, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=6428, ip=192.168.219.101)
#   File "python\ray\_raylet.pyx", line 501, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 451, in ray._raylet.execute_task.function_executor
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\function_manager.py", line 563, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 232, in train
#     result = self.step()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 513, in _report_thread_runner_error
#     ("Trial raised an exception. Traceback:\n{}".format(err_tb_str)
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=6428, ip=192.168.219.101)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
#     self._entrypoint()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
#     return self._get_iterator()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
#     return _MultiProcessingDataLoaderIter(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
#     w.start()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
#     self._popen = self._Popen(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
#     reduction.dump(process_obj, to_child)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# BrokenPipeError: [Errno 32] Broken pipe
# Result for DEFAULT_df0ef_00002:
#   {}
#
# == Status ==
# Memory usage on this node: 13.4/15.9 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 10.0/12 CPUs, 0/1 GPUs, 0.0/6.24 GiB heap, 0.0/3.12 GiB objects
# Result logdir: C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46
# Number of trials: 10/10 (1 ERROR, 4 PENDING, 5 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_df0ef_00000 | RUNNING  |       |            8 |  128 |   16 | 0.00832281  |
# | DEFAULT_df0ef_00001 | RUNNING  |       |           16 |   64 |   64 | 0.038013    |
# | DEFAULT_df0ef_00003 | RUNNING  |       |            4 |    8 |    4 | 0.000381076 |
# | DEFAULT_df0ef_00004 | RUNNING  |       |            2 |   16 |    4 | 0.000174042 |
# | DEFAULT_df0ef_00005 | RUNNING  |       |            4 |    4 |  256 | 0.000789866 |
# | DEFAULT_df0ef_00006 | PENDING  |       |           16 |  128 |  128 | 0.0207728   |
# | DEFAULT_df0ef_00007 | PENDING  |       |            4 |    8 |  256 | 0.00113064  |
# | DEFAULT_df0ef_00008 | PENDING  |       |            8 |   16 |  128 | 0.000982856 |
# | DEFAULT_df0ef_00009 | PENDING  |       |           16 |  128 |    4 | 0.000411013 |
# | DEFAULT_df0ef_00002 | ERROR    |       |            4 |   16 |    4 | 0.0278657   |
# +---------------------+----------+-------+--------------+------+------+-------------+
# Number of errored trials: 1
# +---------------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                                         |
# |---------------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_df0ef_00002 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00002_2_batch_size=4,l1=16,l2=4,lr=0.027866_2021-07-28_00-39-47\error.txt |
# +---------------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Result for DEFAULT_df0ef_00000:
#   {}
#
# Result for DEFAULT_df0ef_00005:
#   {}
# (pid=12976) Windows fatal exception: access violation
# (pid=12976)
# (pid=13480) Windows fatal exception: access violation
# (pid=13480)
# (pid=6428) Windows fatal exception: access violation
# (pid=6428)
# (pid=17160) Files already downloaded and verified
# (pid=8976) Files already downloaded and verified
# (pid=23764) Files already downloaded and verified
# (pid=17160) Files already downloaded and verified
# (pid=8976) Files already downloaded and verified
# (pid=23764) Files already downloaded and verified
# (pid=17160) 2021-07-28 00:40:19,559	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=17160) Traceback (most recent call last):
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=17160)     self._entrypoint()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=17160)     self._status_reporter.get_checkpoint())
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=17160)     output = fn()
# (pid=17160)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=17160)     return self._get_iterator()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=17160)     return _MultiProcessingDataLoaderIter(self)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=17160)     w.start()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=17160)     self._popen = self._Popen(self)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=17160)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=17160)     return Popen(process_obj)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=17160)     reduction.dump(process_obj, to_child)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=17160)     ForkingPickler(file, protocol).dump(obj)
# (pid=17160) OSError: [Errno 22] Invalid argument
# (pid=17160) Exception in thread Thread-2:
# (pid=17160) Traceback (most recent call last):
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\threading.py", line 916, in _bootstrap_inner
# (pid=17160)     self.run()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 267, in run
# (pid=17160)     raise e
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=17160)     self._entrypoint()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=17160)     self._status_reporter.get_checkpoint())
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=17160)     output = fn()
# (pid=17160)   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
# (pid=17160)     return self._get_iterator()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
# (pid=17160)     return _MultiProcessingDataLoaderIter(self)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
# (pid=17160)     w.start()
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
# (pid=17160)     self._popen = self._Popen(self)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
# (pid=17160)     return _default_context.get_context().Process._Popen(process_obj)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
# (pid=17160)     return Popen(process_obj)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
# (pid=17160)     reduction.dump(process_obj, to_child)
# (pid=17160)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
# (pid=17160)     ForkingPickler(file, protocol).dump(obj)
# (pid=17160) OSError: [Errno 22] Invalid argument
# (pid=17160)
# 2021-07-28 00:40:19,776	ERROR trial_runner.py:748 -- Trial DEFAULT_df0ef_00006: Error processing event.
# Traceback (most recent call last):
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py", line 718, in _process_trial
#     results = self.trial_executor.fetch_result(trial)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\ray_trial_executor.py", line 688, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\client_mode_hook.py", line 62, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\worker.py", line 1494, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train_buffered() (pid=17160, ip=192.168.219.101)
#   File "python\ray\_raylet.pyx", line 501, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 451, in ray._raylet.execute_task.function_executor
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\_private\function_manager.py", line 563, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 173, in train_buffered
#     result = self.train()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\trainable.py", line 232, in train
#     result = self.step()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 366, in step
#     self._report_thread_runner_error(block=True)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 513, in _report_thread_runner_error
#     ("Trial raised an exception. Traceback:\n{}".format(err_tb_str)
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train_buffered() (pid=17160, ip=192.168.219.101)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
#     self._entrypoint()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
#     output = fn()
#   File "<ipython-input-4-1f7decf27e71>", line 40, in train_cifar
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 352, in __iter__
#     return self._get_iterator()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 294, in _get_iterator
#     return _MultiProcessingDataLoaderIter(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\torch\utils\data\dataloader.py", line 801, in __init__
#     w.start()
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\process.py", line 105, in start
#     self._popen = self._Popen(self)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 223, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\popen_spawn_win32.py", line 65, in __init__
#     reduction.dump(process_obj, to_child)
#   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# OSError: [Errno 22] Invalid argument
# (pid=8976) 2021-07-28 00:40:19,723	ERROR function_runner.py:254 -- Runner Thread raised error.
# (pid=8976) Traceback (most recent call last):
# (pid=8976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 248, in run
# (pid=8976)     self._entrypoint()
# (pid=8976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 316, in entrypoint
# (pid=8976)     self._status_reporter.get_checkpoint())
# (pid=8976)   File "C:\Users\PARK JIHO\anaconda3\envs\torch\lib\site-packages\ray\tune\function_runner.py", line 580, in _trainable_func
# (pid=8976)     output = fn()
# ...
# | DEFAULT_df0ef_00004 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00004_4_batch_size=2,l1=16,l2=4,lr=0.00017404_2021-07-28_00-39-47\error.txt   |
# | DEFAULT_df0ef_00005 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00005_5_batch_size=4,l1=4,l2=256,lr=0.00078987_2021-07-28_00-39-47\error.txt  |
# | DEFAULT_df0ef_00006 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00006_6_batch_size=16,l1=128,l2=128,lr=0.020773_2021-07-28_00-39-47\error.txt |
# | DEFAULT_df0ef_00007 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00007_7_batch_size=4,l1=8,l2=256,lr=0.0011306_2021-07-28_00-40-10\error.txt   |
# | DEFAULT_df0ef_00008 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00008_8_batch_size=8,l1=16,l2=128,lr=0.00098286_2021-07-28_00-40-10\error.txt |
# +---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# (pid=22428) [5,  2000] loss: 1.951
# Result for DEFAULT_df0ef_00009:
#   accuracy: 0.2848
#   date: 2021-07-28_00-43-28
#   done: false
#   experiment_id: 1c6056f30c4843f092492f6cb727925e
#   hostname: DESKTOP-G26MRLK
#   iterations_since_restore: 5
#   loss: 1.8587878770828248
#   node_ip: 192.168.219.101
#   pid: 22428
#   should_checkpoint: true
#   time_since_restore: 186.14989757537842
#   time_this_iter_s: 36.549498558044434
#   time_total_s: 186.14989757537842
#   timestamp: 1627400608
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: df0ef_00009
#
# == Status ==
# Memory usage on this node: 5.8/15.9 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -2.0200763750076294 | Iter 2.000: -2.2590433113098145 | Iter 1.000: -2.302574312210083
# Resources requested: 2.0/12 CPUs, 0/1 GPUs, 0.0/6.24 GiB heap, 0.0/3.12 GiB objects
# Result logdir: C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46
# Number of trials: 10/10 (9 ERROR, 1 RUNNING)
# +---------------------+----------+-----------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status   | loc                   |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+----------+-----------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_df0ef_00009 | RUNNING  | 192.168.219.101:22428 |           16 |  128 |    4 | 0.000411013 | 1.85879 |     0.2848 |                    5 |
# | DEFAULT_df0ef_00000 | ERROR    |                       |            8 |  128 |   16 | 0.00832281  |         |            |                      |
# | DEFAULT_df0ef_00001 | ERROR    |                       |           16 |   64 |   64 | 0.038013    |         |            |                      |
# | DEFAULT_df0ef_00002 | ERROR    |                       |            4 |   16 |    4 | 0.0278657   |         |            |                      |
# | DEFAULT_df0ef_00003 | ERROR    |                       |            4 |    8 |    4 | 0.000381076 |         |            |                      |
# | DEFAULT_df0ef_00004 | ERROR    |                       |            2 |   16 |    4 | 0.000174042 |         |            |                      |
# | DEFAULT_df0ef_00005 | ERROR    |                       |            4 |    4 |  256 | 0.000789866 |         |            |                      |
# | DEFAULT_df0ef_00006 | ERROR    |                       |           16 |  128 |  128 | 0.0207728   |         |            |                      |
# | DEFAULT_df0ef_00007 | ERROR    |                       |            4 |    8 |  256 | 0.00113064  |         |            |                      |
# | DEFAULT_df0ef_00008 | ERROR    |                       |            8 |   16 |  128 | 0.000982856 |         |            |                      |
# +---------------------+----------+-----------------------+--------------+------+------+-------------+---------+------------+----------------------+
# Number of errored trials: 9
# +---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                                             |
# |---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_df0ef_00000 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00000_0_batch_size=8,l1=128,l2=16,lr=0.0083228_2021-07-28_00-39-46\error.txt  |
# | DEFAULT_df0ef_00001 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00001_1_batch_size=16,l1=64,l2=64,lr=0.038013_2021-07-28_00-39-46\error.txt   |
# | DEFAULT_df0ef_00002 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00002_2_batch_size=4,l1=16,l2=4,lr=0.027866_2021-07-28_00-39-47\error.txt     |
# | DEFAULT_df0ef_00003 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00003_3_batch_size=4,l1=8,l2=4,lr=0.00038108_2021-07-28_00-39-47\error.txt    |
# | DEFAULT_df0ef_00004 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00004_4_batch_size=2,l1=16,l2=4,lr=0.00017404_2021-07-28_00-39-47\error.txt   |
# | DEFAULT_df0ef_00005 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00005_5_batch_size=4,l1=4,l2=256,lr=0.00078987_2021-07-28_00-39-47\error.txt  |
# | DEFAULT_df0ef_00006 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00006_6_batch_size=16,l1=128,l2=128,lr=0.020773_2021-07-28_00-39-47\error.txt |
# | DEFAULT_df0ef_00007 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00007_7_batch_size=4,l1=8,l2=256,lr=0.0011306_2021-07-28_00-40-10\error.txt   |
# | DEFAULT_df0ef_00008 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00008_8_batch_size=8,l1=16,l2=128,lr=0.00098286_2021-07-28_00-40-10\error.txt |
# +---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# (pid=22428) [6,  2000] loss: 1.828
# Result for DEFAULT_df0ef_00009:
#   accuracy: 0.3227
#   date: 2021-07-28_00-44-03
#   done: false
#   experiment_id: 1c6056f30c4843f092492f6cb727925e
#   hostname: DESKTOP-G26MRLK
#   iterations_since_restore: 6
#   loss: 1.774202738571167
#   node_ip: 192.168.219.101
#   pid: 22428
#   should_checkpoint: true
#   time_since_restore: 221.66963911056519
#   time_this_iter_s: 35.51974153518677
#   time_total_s: 221.66963911056519
#   timestamp: 1627400643
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: df0ef_00009
#
# == Status ==
# Memory usage on this node: 5.5/15.9 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -2.0200763750076294 | Iter 2.000: -2.2590433113098145 | Iter 1.000: -2.302574312210083
# Resources requested: 2.0/12 CPUs, 0/1 GPUs, 0.0/6.24 GiB heap, 0.0/3.12 GiB objects
# Result logdir: C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46
# Number of trials: 10/10 (9 ERROR, 1 RUNNING)
# +---------------------+----------+-----------------------+--------------+------+------+-------------+--------+------------+----------------------+
# | Trial name          | status   | loc                   |   batch_size |   l1 |   l2 |          lr |   loss |   accuracy |   training_iteration |
# |---------------------+----------+-----------------------+--------------+------+------+-------------+--------+------------+----------------------|
# | DEFAULT_df0ef_00009 | RUNNING  | 192.168.219.101:22428 |           16 |  128 |    4 | 0.000411013 | 1.7742 |     0.3227 |                    6 |
# | DEFAULT_df0ef_00000 | ERROR    |                       |            8 |  128 |   16 | 0.00832281  |        |            |                      |
# | DEFAULT_df0ef_00001 | ERROR    |                       |           16 |   64 |   64 | 0.038013    |        |            |                      |
# | DEFAULT_df0ef_00002 | ERROR    |                       |            4 |   16 |    4 | 0.0278657   |        |            |                      |
# | DEFAULT_df0ef_00003 | ERROR    |                       |            4 |    8 |    4 | 0.000381076 |        |            |                      |
# | DEFAULT_df0ef_00004 | ERROR    |                       |            2 |   16 |    4 | 0.000174042 |        |            |                      |
# | DEFAULT_df0ef_00005 | ERROR    |                       |            4 |    4 |  256 | 0.000789866 |        |            |                      |
# | DEFAULT_df0ef_00006 | ERROR    |                       |           16 |  128 |  128 | 0.0207728   |        |            |                      |
# | DEFAULT_df0ef_00007 | ERROR    |                       |            4 |    8 |  256 | 0.00113064  |        |            |                      |
# | DEFAULT_df0ef_00008 | ERROR    |                       |            8 |   16 |  128 | 0.000982856 |        |            |                      |
# +---------------------+----------+-----------------------+--------------+------+------+-------------+--------+------------+----------------------+
# Number of errored trials: 9
# +---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                                             |
# |---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_df0ef_00000 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00000_0_batch_size=8,l1=128,l2=16,lr=0.0083228_2021-07-28_00-39-46\error.txt  |
# | DEFAULT_df0ef_00001 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00001_1_batch_size=16,l1=64,l2=64,lr=0.038013_2021-07-28_00-39-46\error.txt   |
# | DEFAULT_df0ef_00002 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00002_2_batch_size=4,l1=16,l2=4,lr=0.027866_2021-07-28_00-39-47\error.txt     |
# | DEFAULT_df0ef_00003 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00003_3_batch_size=4,l1=8,l2=4,lr=0.00038108_2021-07-28_00-39-47\error.txt    |
# | DEFAULT_df0ef_00004 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00004_4_batch_size=2,l1=16,l2=4,lr=0.00017404_2021-07-28_00-39-47\error.txt   |
# | DEFAULT_df0ef_00005 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00005_5_batch_size=4,l1=4,l2=256,lr=0.00078987_2021-07-28_00-39-47\error.txt  |
# | DEFAULT_df0ef_00006 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00006_6_batch_size=16,l1=128,l2=128,lr=0.020773_2021-07-28_00-39-47\error.txt |
# | DEFAULT_df0ef_00007 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00007_7_batch_size=4,l1=8,l2=256,lr=0.0011306_2021-07-28_00-40-10\error.txt   |
# | DEFAULT_df0ef_00008 |            1 | C:\Users\PARK JIHO\ray_results\DEFAULT_2021-07-28_00-39-46\DEFAULT_df0ef_00008_8_batch_size=8,l1=16,l2=128,lr=0.00098286_2021-07-28_00-40-10\error.txt |
# +---------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2021-07-28 00:44:06,642	WARNING tune.py:507 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6e0dad921130> in <module>
#      51 if __name__ == "__main__":
#      52     # You can change the number of GPUs per trial here:
# ---> 53     main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
#
# <ipython-input-6-6e0dad921130> in main(num_samples, max_num_epochs, gpus_per_trial)
#      23         num_samples=num_samples,
#      24         scheduler=scheduler,
# ---> 25         progress_reporter=reporter)
#      26
#      27     best_trial = result.get_best_trial("loss", "min", "last")
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\tune\tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, loggers, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint, _remote)
#     518     tune_start = time.time()
#     519     while not runner.is_finished() and not state[signal.SIGINT]:
# --> 520         runner.step()
#     521         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     522             _report_progress(runner, progress_reporter)
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py in step(self)
#     539                 if self.trial_executor.in_staging_grace_period():
#     540                     timeout = 0.1
# --> 541                 self._process_events(timeout=timeout)  # blocking
#     542             else:
#     543                 self.trial_executor.on_no_available_trials(self)
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\tune\trial_runner.py in _process_events(self, timeout)
#     652             #  fetch_result functionality so that we don't timeout on fetch.
#     653             trial = self.trial_executor.get_next_available_trial(
# --> 654                 timeout=timeout)  # blocking
#     655             if not trial:
#     656                 return
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\tune\ray_trial_executor.py in get_next_available_trial(self, timeout)
#     658         # See https://github.com/ray-project/ray/issues/4211 for details.
#     659         start = time.time()
# --> 660         ready, _ = ray.wait(shuffled_results, timeout=timeout)
#     661         if not ready:
#     662             return None
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#      60         if client_mode_should_convert():
#      61             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 62         return func(*args, **kwargs)
#      63
#      64     return wrapper
#
# ~\anaconda3\envs\torch\lib\site-packages\ray\worker.py in wait(object_refs, num_returns, timeout, fetch_local)
#    1634             timeout_milliseconds,
#    1635             worker.current_task_id,
# -> 1636             fetch_local,
#    1637         )
#    1638         return ready_ids, remaining_ids
#
# python\ray\_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python\ray\_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:
