# %% [markdown]
# # resizing and flipping

# %%
import cv2
import matplotlib.pyplot as plt

def show_img(name, img):
    cv2.imshow(name, img)

# %%
img = cv2.imread('../data/Lena.png')
print('original image shape:', img.shape)
plt.imshow(img[...,::-1])
# show_img('ori', img)
# Out:
# original image shape: (512, 512, 3)

# %%
width, height = 128, 256
resized_img = cv2.resize(img, (width, height))
print('resized image shape:', resized_img.shape)
plt.imshow(resized_img[...,::-1])
# show_img('re', resized_img)
# Out:
# resized image shape: (256, 128, 3)

# %%
w_mult, h_mult = 2, 4
resized_img = cv2.resize(img, (0, 0), resized_img, w_mult, h_mult, cv2.INTER_NEAREST)
print('half sized image shape:', resized_img.shape)
plt.imshow(resized_img[...,::-1])
# show_img('re2', resized_img)
# Out:
# half sized image shape: (2048, 1024, 3)

# %%
img_flip_along_x = cv2.flip(img, 0)
plt.imshow(img_flip_along_x[...,::-1])
# show_img('flip1', img_flip_along_x)

# %%
img_flip_along_y = cv2.flip(img, 1)
plt.imshow(img_flip_along_y[...,::-1])
# show_img('flip2', img_flip_along_y)

# %%
img_flip_along_xy = cv2.flip(img, -1)
plt.imshow(img_flip_along_xy[...,::-1])
# show_img('flip3', img_flip_along_xy)

# %%
# cv2.waitKey(0)
# cv2.destroyAllWindows()
